# %%
import torch
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.insert(0, './src')
from data import Dataset
from training import train
from plotting import plot_mfg_classification, plot_mcdo_classification, mfg_regression_inference, mcdo_regression_inference, plot_pred_to_true
from metrics import log_likelihood, log_likelihood_errors

# %%
def set_seeds(rand_seed):
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.manual_seed(rand_seed)
    np.random.seed(rand_seed)
    random.seed(rand_seed)
    torch.cuda.manual_seed_all(rand_seed)

set_seeds(1337)

# %%
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

# %% [markdown]
# ```python
# DATASETS = {
#     'boston_housing': BostonHousingData,
#     'concrete': ConcreteData,
#     'energy_efficiency': EnergyEfficiencyData,
#     'kin8nm': Kin8nmData,
#     'naval_propulsion': NavalPropulsionData,
#     'ccpp': CCPPData,
#     'protein_structure': ProteinStructureData,
#     'red_wine': RedWineData,
#     'yacht_hydrodynamics': YachtHydrodynamicsData,
#     'year_prediction_msd': YearPredictionMSDData,
#     'mnist': MnistData,
#     'fashion_mnist': FashionMnistData,
#     'cifar_10': Cifar10,
#     'svhn': SVHN
# }
# ```

# %%
args = dotdict({})

# %%
args['device'] = 'cuda:0' if torch.cuda.is_available() else 'cpu'
args['torchType'] = torch.float32

args['model_type'] = 'mcdo' # 'mcdo', 'mfg'
args['dataset_name'] = 'energy_efficiency'
if args['dataset_name'].find('mnist') > -1:
    args['num_epoches'] = 201
    args['print_info'] = 50
    args['n_IS'] = 10000
    
    args['train_batch_size'] = 100
    args['val_dataset'] = 10000
    args['val_batch_size'] = 100
    args['test_batch_size'] = 100
else:
    args['n_IS'] = 1000
    args['num_epoches'] = 3001
    args['print_info'] = 1000
    args['train_batch_size'] = 75
    args['val_dataset'] = 200
    args['val_batch_size'] = 20
    args['test_batch_size'] = 10

# %%
dataset = Dataset(args)
dataset.in_features
# Out:
# Loading dataset...
# Train data shape 568
# (8,)

# %%
# model, params = train(args, dataset)

# %%
# obj_id = 21

# if args.problem == 'classification':
#     if args.model_type == 'mfg':
#         plot_mfg_classification(args, model, dataset, params)
#     elif args.model_type == 'mcdo':
#         plot_mcdo_classification(args, model, dataset, params)
# else:
#     if args.model_type == 'mfg':
#         mfg_regression_inference(args, model, dataset, params, obj_id)
#     elif args.model_type == 'mcdo':
#         mcdo_regression_inference(args, model, dataset, params, obj_id)

# %% [markdown]
# ## Comparison of MFG and MCDO

# %%
## MFG
args['model_type'] = 'mfg' # 'mcdo', 'mfg'
model_mfg, params_mfg = train(args, dataset)
# Out:
#   0%|          | 5/3001 [00:00<01:00, 49.48it/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 16]             144
#             Linear-2                [-1, 1, 10]             170
#           Softplus-3                [-1, 1, 10]               0
# ================================================================
# Total params: 314
# Trainable params: 314
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# ELBO value is -10433.392578125 on epoch number 0
# Mean validation MSE at epoch number 0 is 357.6506652832031
# Current KL is 1.1976885795593262
#  34%|███▎      | 1007/3001 [00:19<00:37, 52.59it/s]
# ELBO value is -3002.70947265625 on epoch number 1000
# Mean validation MSE at epoch number 1000 is 21.495206832885742
# Current KL is 1.7772586345672607
#  67%|██████▋   | 2009/3001 [00:37<00:18, 53.18it/s]
# ELBO value is -228.7189178466797 on epoch number 2000
# Mean validation MSE at epoch number 2000 is 12.66670036315918
# Current KL is 3.1550421714782715
# 100%|██████████| 3001/3001 [00:56<00:00, 53.18it/s]
# ELBO value is -122.83724975585938 on epoch number 3000
# Mean validation MSE at epoch number 3000 is 8.5581636428833
# Current KL is 3.8317079544067383

# %%
## MCDO
args['model_type'] = 'mcdo' # 'mcdo', 'mfg'
model_mcdo, params_mcdo = train(args, dataset)
# Out:
#   0%|          | 8/3001 [00:00<00:39, 75.07it/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 16]             144
#             Linear-2                [-1, 1, 10]             170
#           Softplus-3                [-1, 1, 10]               0
# ================================================================
# Total params: 314
# Trainable params: 314
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# Log likelihood value is -1337161.5 on epoch number 0
# Mean validation MSE at epoch number 0 is 27025.55078125
#  34%|███▎      | 1009/3001 [00:12<00:25, 79.25it/s]
# Log likelihood value is -1889.46826171875 on epoch number 1000
# Mean validation MSE at epoch number 1000 is 29.7728271484375
#  67%|██████▋   | 2009/3001 [00:25<00:12, 77.66it/s]
# Log likelihood value is -1075.7403564453125 on epoch number 2000
# Mean validation MSE at epoch number 2000 is 20.129634857177734
# 100%|██████████| 3001/3001 [00:38<00:00, 78.15it/s]
# Log likelihood value is -582.81884765625 on epoch number 3000
# Mean validation MSE at epoch number 3000 is 20.284517288208008

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

if args.problem == 'regression':
    svr = SVR()
    gridcv = GridSearchCV(svr,
                         param_grid={
                            'C': [0.001, 0.01, 0.1, 1., 10.],
                             'epsilon': [0.01, 0.1, 1., 10],
                             'gamma': ['auto', 'scale'],
                          },
                          cv=5,
                          iid=True
                         )
    gridcv.fit(dataset.x_train, dataset.y_train.ravel())
    print(f'SVR\'s MSE validation score: {mean_squared_error(dataset.y_val, gridcv.predict(dataset.x_val))}')
# Out:
# SVR's MSE validation score: 5.790289239296812

# %% [markdown]
# ### Likelihood estimation of errors (in normal assumption)

# %%
args['model_type'] = 'mfg' # 'mcdo', 'mfg'
mfg_ll = log_likelihood_errors(model_mfg, params_mfg, dataset, args)
print(f'MFG error\'s loglikelihood is {mfg_ll}')

args['model_type'] = 'mcdo' # 'mcdo', 'mfg'
mcdo_ll = log_likelihood_errors(model_mcdo, params_mcdo, dataset, args)
print(f'MCDO error\'s loglikelihood is {mcdo_ll}')
# Out:
# 10it [00:01,  6.34it/s]
# 2it [00:00, 16.94it/s]
# MFG error's loglikelihood is -27.1569881439209
# 10it [00:00, 16.77it/s]
# MCDO error's loglikelihood is -13.023938179016113

# %% [markdown]
# ### Pred to true plot

# %%
for model_type in ['mfg', 'mcdo']:
    args['model_type'] = model_type
    model = globals()[f'model_{model_type}']
    params = globals()[f'params_{model_type}']
    examples, true_ans, pred_ans, pred_std = plot_pred_to_true(args, model, dataset, params, name=model_type)
    globals()[f'preds_{model_type}'] = pred_ans
    globals()[f'stds_{model_type}'] = pred_std
# Out:
# 10it [00:01,  5.52it/s]
# 10it [00:00, 12.17it/s]

# %%
sk_pred = gridcv.predict(examples)

plt.figure(figsize=(15, 8), dpi=300)
plt.title('Sklearn model')
plt.plot(true_ans, sk_pred, '-..')
plt.xlabel('y_true')
plt.ylabel('y_pred')
plt.axis('equal')
plt.xlim(true_ans.min(), true_ans.max())
plt.ylim(true_ans.min(), true_ans.max())
plt.xticks(ticks=np.linspace(true_ans.min(), true_ans.max(), 10))
plt.yticks(ticks=np.linspace(true_ans.min(), true_ans.max(), 10))
plt.plot([true_ans.min(), true_ans.max()], [true_ans.min(), true_ans.max()], linewidth=6, c='r', label='perfect fit')
plt.legend()
plt.show();

# %% [markdown]
# ### Likelihood estimation

# %%
args['model_type'] = 'mfg' # 'mcdo', 'mfg'
mfg_ll = log_likelihood(model_mfg, params_mfg, dataset, args)

args['model_type'] = 'mcdo' # 'mcdo', 'mfg'
mcdo_ll = log_likelihood(model_mcdo, params_mcdo, dataset, args)

# %%
print(f'Mean-Field-Gaussian loglikelihood: {np.mean(mfg_ll)} +/- {np.std(mfg_ll)}')
print(f'Monte-Carlo Dropout loglikelihood: {np.mean(mcdo_ll)} +/- {np.std(mcdo_ll)}')
# Out:
# Mean-Field-Gaussian loglikelihood: -9.44112829208374 +- 2.0521901661063016
# Monte-Carlo Dropout loglikelihood: -0.2614870929718018 +- 0.04902956887986008

# %% [markdown]
# $p_\theta(x, w) = p_\theta(x|w)p(w)$

# %% [markdown]
# $\log p_\theta(x) = \log \int_w p_\theta(x, w)dw = \log \int_w p_\theta(x|w)p(w)dw = \log \frac{1}{N_{is}} \sum_{i=1}^{N_{is}} p_\theta(x|w_i)$, w_i ~ p(w)

# %% [markdown]
# $\log p_\theta(x) = \log \int_w \frac{p_\theta(x, w)}{q_\phi(w|x)} q_\phi(w|x) dw = \log \frac{1}{N_{is}} \sum_{i=1}^{N_{is}} \frac{p_\theta(x, w_i)}{q_\phi(w_i|x)} = \log \frac{1}{N_{is}} \sum_{i=1}^{N_{is}} \frac{p_\theta(x| w_i) p(w_i)}{q_\phi(w_i|x)}$

# %% [markdown]
# ## Inference Examples

# %%
plot_mfg_classification(args, model_mfg, dataset, params_mfg)
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-8ca1f1cc53f8> in <module>
# ----> 1 plot_mfg_classification(args, model_mfg, dataset, params_mfg)
#
# ~/github/bnn/src/plotting.py in plot_mfg_classification(args, model, dataset, params)
#      58                     probs = torch.softmax(logits, dim=-1)
#      59                     y_pred = torch.argmax(probs, dim=-1)
# ---> 60                     results.append(y_pred.cpu().item())
#      61             if np.unique(results).shape[0] > 1: # or np.unique(results)[0] != test_label:
#      62                 print('-' * 100)
#
# KeyboardInterrupt:

# %%
plot_mcdo_classification(args, model_mcdo, dataset, params_mcdo)gridsv
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-6690a93bbdff> in <module>
# ----> 1 plot_mcdo_classification(args, model_mcdo, dataset, params_mcdo)
#
# ~/github/bnn/src/plotting.py in plot_mcdo_classification(args, model, dataset, params)
#     131
#     132                 labels, counts = np.unique(results, return_counts=True)
# --> 133                 plt.bar(labels, counts, align='center')
#     134                 plt.xticks(ticks=np.arange(10))
#     135                 plt.xlim((-1, 10));
#
# ~/anaconda3/envs/condatorch/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# ~/anaconda3/envs/condatorch/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/condatorch/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2473             ymin = max(ymin * 0.9, 1e-100)
#    2474             self.dataLim.intervaly = (ymin, ymax)
# -> 2475         self.autoscale_view()
#    2476
#    2477         bar_container = BarContainer(patches, errorbar, label=label)
#
# ~/anaconda3/envs/condatorch/lib/python3.7/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2496         handle_single_axis(
#    2497             scaley, self._autoscaleYon, self._shared_y_axes, 'intervaly',
# -> 2498             'minposy', self.yaxis, self._ymargin, y_stickies, self.set_ybound)
#    2499
#    2500     def _get_axis_list(self):
#
# ~/anaconda3/envs/condatorch/lib/python3.7/site-packages/matplotlib/axes/_base.py in handle_single_axis(scale, autoscaleon, shared_axes, interval, minpos, axis, margin, stickies, set_bound)
#    2487
#    2488             if not self._tight:
# -> 2489                 x0, x1 = locator.view_limits(x0, x1)
#    2490             set_bound(x0, x1)
#    2491             # End of definition of internal function 'handle_single_axis'.
#
# ~/anaconda3/envs/condatorch/lib/python3.7/site-packages/matplotlib/ticker.py in view_limits(self, dmin, dmax)
#    2101
#    2102         dmin, dmax = mtransforms.nonsingular(
# -> 2103             dmin, dmax, expander=1e-12, tiny=1e-13)
#    2104
#    2105         if rcParams['axes.autolimit_mode'] == 'round_numbers':
#
# ~/anaconda3/envs/condatorch/lib/python3.7/site-packages/matplotlib/transforms.py in nonsingular(vmin, vmax, expander, tiny, increasing)
#    2825         swapped = True
#    2826
# -> 2827     maxabsvalue = max(abs(vmin), abs(vmax))
#    2828     if maxabsvalue < (1e6 / tiny) * np.finfo(float).tiny:
#    2829         vmin = -expander
#
# KeyboardInterrupt:

# %%
mfg_regression_inference(args, model_mfg, dataset, params_mfg, val_id=0)
# Out:
# tensor([21.7000], device='cuda:0')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d0a6d9cadf2a> in <module>
# ----> 1 mfg_regression_inference(args, model_mfg, dataset, params_mfg, val_id=0)
#
# ~/github/bnn/src/plotting.py in mfg_regression_inference(args, model, dataset, params, val_id)
#     155             if args.problem == 'classification':
#     156                 emb = model(test_image[None, None, ...])
# --> 157             else:
#     158                 emb = model(test_image[None,  ...])
#     159             last_weight = last_weight_mu + std_normal.sample(last_weight_mu.shape) * torch.exp(0.5 * last_weight_logvar)
#
# NameError: name 'std_normal' is not defined

# %%
mcdo_regression_inference(args, model_mcdo, dataset, params_mcdo, val_id=0)
# Out:
# tensor([21.7000], device='cuda:0')
# Marginalized answer  21.751021728515624
# True answer tensor([21.7000], device='cuda:0')
# ----------------------------------------------------------------------------------------------------
# Parameters are:
# Weight:
# Mean is
#  [[-1.1543107 ]
#  [ 1.53413   ]
#  [-1.686492  ]
#  [ 0.5431452 ]
#  [-0.03910854]
#  [ 1.3241545 ]
#  [-0.30524686]
#  [-0.48447663]
#  [ 2.9014547 ]
#  [-0.29886362]]
# ----------------------------------------------------------------------------------------------------
# Parameters are:
# Bias:
# Mean is
#  [[22.657314]]
